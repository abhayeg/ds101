# %%
import pandas as pd
from pandas import DataFrame
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from scipy.stats import norm, kurtosis, skew
#from wordcloud import WordCloud, STOPWORDS
pd.options.display.float_format = '{:,.1f}'.format

sns.set()
# %matplotlib inline

# %%
dfarti = pd.read_excel('gapstat.xlsx')
dfapp = pd.read_excel('statsapp.xlsx')

# %%
dfapp
# Out:
#   appno       19.1       19.2           19.3       19.4       19.5       19.6  \
# 0  app1  Compliant  Compliant  Clarification        Gap  Compliant  Compliant
# 1  app2  Compliant        Gap      Compliant  Compliant  Compliant        Gap
# 2  app3  Compliant  Compliant      Compliant        Gap  Compliant  Compliant
# 3  app4  Compliant  Compliant  Clarification  Compliant        Gap  Compliant
# 4  app5  Compliant  Compliant            Gap  Compliant  Compliant  Compliant
#
#         19.7       19.8       19.9             20           20.1  \
# 0    NotAppl  Compliant    NotAppl      Compliant  Clarification
# 1  Compliant  Compliant  Compliant            Gap      Compliant
# 2        Gap  Compliant  Compliant  Clarification  Clarification
# 3    NotAppl  Compliant  Compliant      Compliant  Clarification
# 4        Gap  Compliant  Compliant      Compliant  Clarification
#
#             20.2       20.3     20.4       20.5           20.6           20.7  \
# ...

# %%
app = dfapp['appno'].tolist()
art19_1 = dfapp[19.1].tolist()
art19_2 = dfapp[19.2].tolist()
art19_3 = dfapp[19.3].tolist()
art19_4 = dfapp[19.4].tolist()
art19_5 = dfapp[19.5].tolist()
art19_6 = dfapp[19.6].tolist()
art19_7 = dfapp[19.7].tolist()
art19_8 = dfapp[19.8].tolist()
art19_9 = dfapp[19.9].tolist()
art20 = dfapp[20].tolist()
art20_1 = dfapp[20.1].tolist()
art20_2 = dfapp[20.2].tolist()
art20_3 = dfapp[20.3].tolist()
art20_4 = dfapp[20.4].tolist()
art20_5 = dfapp[20.5].tolist()
art20_6 = dfapp[20.6].tolist()
art20_7 = dfapp[20.7].tolist()
art20_8 = dfapp[20.8].tolist()

# %%
artstat={}
artstat['AppName'] = app
artstat['19.1'] = art19_1
artstat['19.2'] = art19_2
artstat['19.3'] = art19_3 
artstat['19.4'] = art19_4 
artstat['19.5'] = art19_5 
artstat['19.6'] = art19_6 
artstat['19.7'] = art19_7 
artstat['19.8'] = art19_8 
artstat['19.9'] = art19_9 
artstat['20'] = art20 
artstat['20.1'] = art20_1 
artstat['20.2'] = art20_2 
artstat['20.3'] = art20_3 
artstat['20.4'] = art20_4 
artstat['20.5'] = art20_5 
artstat['20.6'] = art20_6 
artstat['20.7'] = art20_7 
artstat['20.8'] = art20_8

# %%
artstat
# Out:
# {'19.1': ['Compliant', 'Compliant', 'Compliant', 'Compliant', 'Compliant'],
#  '19.2': ['Compliant', 'Gap', 'Compliant', 'Compliant', 'Compliant'],
#  '19.3': ['Clarification', 'Compliant', 'Compliant', 'Clarification', 'Gap'],
#  '19.4': ['Gap', 'Compliant', 'Gap', 'Compliant', 'Compliant'],
#  '19.5': ['Compliant', 'Compliant', 'Compliant', 'Gap', 'Compliant'],
#  '19.6': ['Compliant', 'Gap', 'Compliant', 'Compliant', 'Compliant'],
#  '19.7': ['NotAppl', 'Compliant', 'Gap', 'NotAppl', 'Gap'],
#  '19.8': ['Compliant', 'Compliant', 'Compliant', 'Compliant', 'Compliant'],
#  '19.9': ['NotAppl', 'Compliant', 'Compliant', 'Compliant', 'Compliant'],
#  '20': ['Compliant', 'Gap', 'Clarification', 'Compliant', 'Compliant'],
#  '20.1': ['Clarification',
#   'Compliant',
#   'Clarification',
#   'Clarification',
#   'Clarification'],
#  '20.2': ['Clarification', 'Gap', 'Compliant', 'Gap', 'Clarification'],
#  '20.3': ['Compliant', 'Compliant', 'Compliant', 'Compliant', 'Compliant'],
# ...

# %%
c="Compliant"
g="Gap"
n="NotAppl"
cl="Clarification"

tc = 0
tg = 0 
tn = 0
tcl = 0

c191=0
g191=0
n191 =0
cl191=0

c192=0
g192=0
n192 =0
cl192=0

c193=0
g193=0
n193 =0
cl193=0

c194=0
g194=0
n194 =0
cl194=0

c195=0
g195=0
n195 =0
cl195=0

c196=0
g196=0
n196 =0
cl196=0

c197=0
g197=0
n197 =0
cl197=0

c198=0
g198=0
n198 =0
cl198=0

c199=0
g199=0
n199 =0
cl199=0

c20=0
g20=0
n20 =0
cl20=0

c201=0
g201=0
n201 =0
cl201=0

c202=0
g202=0
n202 =0
cl202=0

c203=0
g203=0
n203 =0
cl203=0

c204=0
g204=0
n204 =0
cl204=0

c205=0
g205=0
n205 =0
cl205=0

c206=0
g206=0
n206 =0
cl206=0

c207=0
g207=0
n207 =0
cl207=0

c208=0
g208=0
n208 =0
cl208=0

for i in range(0,5):
    if artstat["19.1"][i] ==c:
        c191 = c191 + 1
        tc = tc + 1
    elif artstat["19.1"][i] ==g:
        g191= g191 + 1
        tg = tg + 1
    elif artstat["19.1"][i] ==n:
        n191= n191 + 1
        tn = tn + 1
    elif artstat["19.1"][i] ==cl:
        cl191= cl191 + 1
        tcl = tcl  + 1
        
    if artstat["19.2"][i] ==c:
        c192 = c192 + 1
        tc = tc + 1
    elif artstat["19.2"][i] ==g:
        g192= g192 + 1
        tg = tg + 1
    elif artstat["19.2"][i] ==n:
        n192= n192 + 1
        tn = tn + 1
    elif artstat["19.2"][i] ==cl:
        cl192= cl192 + 1
        tcl = tcl  + 1
        
    if artstat["19.3"][i] ==c:
        c193 = c193 + 1
        tc = tc + 1
    elif artstat["19.3"][i] ==g:
        g193= g193 + 1
        tg = tg + 1
    elif artstat["19.3"][i] ==n:
        n193= n193 + 1
        tn = tn + 1
    elif artstat["19.3"][i] ==cl:
        cl193= cl193 + 1
        tcl = tcl  + 1
        
    if artstat["19.4"][i] ==c:
        c194 = c194 + 1
        tc = tc + 1
    elif artstat["19.4"][i] ==g:
        g194= g194 + 1
        tg = tg + 1
    elif artstat["19.4"][i] ==n:
        n194= n194 + 1
        tn = tn + 1
    elif artstat["19.4"][i] ==cl:
        cl194= cl194 + 1
        tcl = tcl  + 1
    
    if artstat["19.5"][i] ==c:
        c195 = c195 + 1
        tc = tc + 1
    elif artstat["19.5"][i] ==g:
        g195= g195 + 1
        tg = tg + 1
    elif artstat["19.5"][i] ==n:
        n195= n195 + 1
        tn = tn + 1
    elif artstat["19.5"][i] ==cl:
        cl195= cl195 + 1
        tcl = tcl  + 1

    if artstat["19.6"][i] ==c:
        c196 = c196 + 1
        tc = tc + 1
    elif artstat["19.6"][i] ==g:
        g196= g196 + 1
        tg = tg + 1
    elif artstat["19.6"][i] ==n:
        n196= n196 + 1
        tn = tn + 1
    elif artstat["19.6"][i] ==cl:
        cl196= cl196 + 1
        tcl = tcl  + 1
        
    if artstat["19.7"][i] ==c:
        c197 = c197 + 1
        tc = tc + 1
    elif artstat["19.7"][i] ==g:
        g197= g197 + 1
        tg = tg + 1
    elif artstat["19.7"][i] ==n:
        n197= n197 + 1
        tn = tn + 1
    elif artstat["19.7"][i] ==cl:
        cl197= cl197 + 1
        tcl = tcl  + 1

    if artstat["19.8"][i] ==c:
        c198 = c198 + 1
        tc = tc + 1
    elif artstat["19.8"][i] ==g:
        g198= g198 + 1
        tg = tg + 1
    elif artstat["19.8"][i] ==n:
        n198= n198 + 1
        tn = tn + 1
    elif artstat["19.8"][i] ==cl:
        cl198= cl198 + 1 
        tcl = tcl  + 1

    if artstat["19.9"][i] ==c:
        c199 = c199 + 1
        tc = tc + 1
    elif artstat["19.9"][i] ==g:
        g199= g199 + 1
        tg = tg + 1
    elif artstat["19.9"][i] ==n:
        n199= n199 + 1
        tn = tn + 1
    elif artstat["19.9"][i] ==cl:
        cl199= cl199 + 1 
        tcl = tcl  + 1

    if artstat["20"][i] ==c:
        c20 = c20 + 1
        tc = tc + 1
    elif artstat["20"][i] ==g:
        g20= g20 + 1
        tg = tg + 1
    elif artstat["20"][i] ==n:
        n20= n20 + 1
        tn = tn + 1
    elif artstat["20"][i] ==cl:
        cl20= cl20 + 1 
        tcl = tcl  + 1
        
    if artstat["20.1"][i] ==c:
        c201 = c201 + 1
        tc = tc + 1
    elif artstat["20.1"][i] ==g:
        g201= g201 + 1
        tg = tg + 1
    elif artstat["20.1"][i] ==n:
        n201= n201 + 1
        tn = tn + 1
    elif artstat["20.1"][i] ==cl:
        cl201= cl201 + 1
        tcl = tcl  + 1
        
    if artstat["20.2"][i] ==c:
        c202 = c202 + 1
        tc = tc + 1
    elif artstat["20.2"][i] ==g:
        g202= g202 + 1
        tg = tg + 1
    elif artstat["20.2"][i] ==n:
        n202= n202 + 1
        tn = tn + 1
    elif artstat["20.2"][i] ==cl:
        cl202= cl202 + 1
        tcl = tcl  + 1
        
    if artstat["20.3"][i] ==c:
        c203 = c203 + 1
        tc = tc + 1
    elif artstat["20.3"][i] ==g:
        g203= g203 + 1
        tg = tg + 1
    elif artstat["20.3"][i] ==n:
        n203= n203 + 1
        tn = tn + 1
    elif artstat["20.3"][i] ==cl:
        cl203= cl203 + 1
        tcl = tcl  + 1

    if artstat["20.4"][i] ==c:
        c204 = c204 + 1
        tc = tc + 1
    elif artstat["20.4"][i] ==g:
        g204= g204 + 1
        tg = tg + 1
    elif artstat["20.4"][i] ==n:
        n204= n204 + 1
        tn = tn + 1
    elif artstat["20.4"][i] ==cl:
        cl204= cl204 + 1
        tcl = tcl  + 1

    if artstat["20.5"][i] ==c:
        c205 = c205 + 1
        tc = tc + 1
    elif artstat["20.5"][i] ==g:
        g205= g205 + 1
        tg = tg + 1
    elif artstat["20.5"][i] ==n:
        n205= n205 + 1
        tn = tn + 1
    elif artstat["20.5"][i] ==cl:
        cl205= cl205 + 1
        tcl = tcl  + 1

    if artstat["20.6"][i] ==c:
        c206 = c206 + 1
        tc = tc + 1
    elif artstat["20.6"][i] ==g:
        g206= g206 + 1
        tg = tg + 1
    elif artstat["20.6"][i] ==n:
        n206= n206 + 1
        tn = tn + 1
    elif artstat["20.6"][i] ==cl:
        cl206= cl206 + 1
        tcl = tcl  + 1

    if artstat["20.7"][i] ==c:
        c207 = c207 + 1
        tc = tc + 1
    elif artstat["20.7"][i] ==g:
        g207= g207 + 1
        tg = tg + 1
    elif artstat["20.7"][i] ==n:
        n207= n207 + 1
        tn = tn + 1
    elif artstat["20.7"][i] ==cl:
        cl207= cl207 + 1
        tcl = tcl  + 1

    if artstat["20.8"][i] ==c:
        c208 = c208 + 1
        tc = tc + 1
    elif artstat["20.8"][i] ==g:
        g208= g208 + 1
        tg = tg + 1
    elif artstat["20.8"][i] ==n:
        n208= n208 + 1
        tn = tn + 1
    elif artstat["20.8"][i] ==cl:
        cl208= cl208 + 1
        tcl = tcl  + 1





print("---------------------19.1--------------------") 

print("Complied for 19.1       :" , str(c191))
print("Gap Identifed for 19.1  :" , str(g191))
print("Not Applicable for 19.1 :" , str(n191))
print("Clarifiction for 19.1   :" , str(cl191))

print("---------------------19.2--------------------") 
print("Complied for 19.2       :" , str(c192))
print("Gap Identifed for 19.2  :" , str(g192))
print("Not Applicable for 19.2 :" , str(n192))
print("Clarifiction for 19.2   :" , str(cl192))

print("---------------------19.3--------------------") 

print("Complied for 19.3       :" , str(c193))
print("Gap Identifed for 19.3  :" , str(g193))
print("Not Applicable for 19.3 :" , str(n193))
print("Clarifiction for 19.3   :" , str(cl193))

print("---------------------19.4--------------------") 

print("Complied for 19.4       :" , str(c194))
print("Gap Identifed for 19.4  :" , str(g194))
print("Not Applicable for 19.4 :" , str(n194))
print("Clarifiction for 19.4   :" , str(cl194))

print("---------------------19.5--------------------") 

print("Complied for 19.5       :" , str(c195))
print("Gap Identifed for 19.5  :" , str(g195))
print("Not Applicable for 19.5 :" , str(n195))
print("Clarifiction for 19.5   :" , str(cl195))

print("---------------------19.6--------------------") 

print("Complied for 19.6       :" , str(c196))
print("Gap Identifed for 19.6  :" , str(g196))
print("Not Applicable for 19.6 :" , str(n196))
print("Clarifiction for 19.6   :" , str(cl196))

print("---------------------19.7--------------------") 

print("Complied for 19.7       :" , str(c197))
print("Gap Identifed for 19.7  :" , str(g197))
print("Not Applicable for 19.7 :" , str(n197))
print("Clarifiction for 19.7   :" , str(cl197))

print("---------------------19.8--------------------") 

print("Complied for 19.8       :" , str(c198))
print("Gap Identifed for 19.8  :" , str(g198))
print("Not Applicable for 19.8 :" , str(n198))
print("Clarifiction for 19.8   :" , str(cl198))

print("---------------------19.9--------------------") 

print("Complied for 19.9       :" , str(c199))
print("Gap Identifed for 19.9  :" , str(g199))
print("Not Applicable for 19.9 :" , str(n199))
print("Clarifiction for 19.9   :" , str(cl199))

print("---------------------20--------------------") 

print("Complied for 20       :" , str(c20))
print("Gap Identifed for 20  :" , str(g20))
print("Not Applicable for 20 :" , str(n20))
print("Clarifiction for 20   :" , str(cl20))

print("---------------------20.1--------------------") 

print("Complied for 20.1       :" , str(c201))
print("Gap Identifed for 20.1  :" , str(g201))
print("Not Applicable for 20.1 :" , str(n201))
print("Clarifiction for 20.1   :" , str(cl201))

print("---------------------20.2--------------------") 

print("Complied for 20.2       :" , str(c202))
print("Gap Identifed for 20.2  :" , str(g202))
print("Not Applicable for 20.2 :" , str(n202))
print("Clarifiction for 20.2   :" , str(cl202))

print("---------------------20.3--------------------") 

print("Complied for 20.3       :" , str(c203))
print("Gap Identifed for 20.3  :" , str(g203))
print("Not Applicable for 20.3 :" , str(n203))
print("Clarifiction for 20.3   :" , str(cl203))

print("---------------------20.4--------------------") 

print("Complied for 20.4       :" , str(c204))
print("Gap Identifed for 20.4  :" , str(g204))
print("Not Applicable for 20.4 :" , str(n204))
print("Clarifiction for 20.4   :" , str(cl204))

print("---------------------20.5--------------------") 

print("Complied for 20.5       :" , str(c205))
print("Gap Identifed for 20.5  :" , str(g205))
print("Not Applicable for 20.5 :" , str(n205))
print("Clarifiction for 20.5   :" , str(cl205))

print("---------------------20.6--------------------") 

print("Complied for 20.6       :" , str(c206))
print("Gap Identifed for 20.6  :" , str(g206))
print("Not Applicable for 20.6 :" , str(n206))
print("Clarifiction for 20.6   :" , str(cl206))

print("---------------------20.7--------------------") 

print("Complied for 20.7       :" , str(c207))
print("Gap Identifed for 20.7  :" , str(g207))
print("Not Applicable for 20.7 :" , str(n207))
print("Clarifiction for 20.7   :" , str(cl207))

print("---------------------20.8--------------------") 

print("Complied for 20.8       :" , str(c208))
print("Gap Identifed for 20.8  :" , str(g208))
print("Not Applicable for 20.8 :" , str(n208))
print("Clarifiction for 20.8   :" , str(cl208))



print("---------------------Summary------------------------------") 

print("Total Number of Articles                          :" , str(len(artstat)))
print("Total Gaps across all the articles                :" , str(tg))
print("Total Complied across all the articles            :" , str(tc))
print("Total Clarification across all the articles       :" , str(tcl))
print("Total Not Applicable across all the articles      :" , str((tn)))
print("---------------------Total---------------------------------") 
print("Total of All the values                           :" , str(tg+tc+tcl+tn))
print("-----------------------------------------------------------")
# Out:
# ---------------------19.1--------------------
# Complied for 19.1       : 5
# Gap Identifed for 19.1  : 0
# Not Applicable for 19.1 : 0
# Clarifiction for 19.1   : 0
# ---------------------19.2--------------------
# Complied for 19.2       : 4
# Gap Identifed for 19.2  : 1
# Not Applicable for 19.2 : 0
# Clarifiction for 19.2   : 0
# ---------------------19.3--------------------
# Complied for 19.3       : 2
# Gap Identifed for 19.3  : 1
# Not Applicable for 19.3 : 0
# Clarifiction for 19.3   : 2
# ---------------------19.4--------------------
# Complied for 19.4       : 3
# Gap Identifed for 19.4  : 2
# Not Applicable for 19.4 : 0
# Clarifiction for 19.4   : 0
# ---------------------19.5--------------------
# Complied for 19.5       : 4
# Gap Identifed for 19.5  : 1
# Not Applicable for 19.5 : 0
# Clarifiction for 19.5   : 0
# ---------------------19.6--------------------
# Complied for 19.6       : 4
# Gap Identifed for 19.6  : 1
# Not Applicable for 19.6 : 0
# ...

# %%
artstat
# Out:
# {'19.1': ['Compliant', 'Compliant', 'Compliant', 'Compliant', 'Compliant'],
#  '19.2': ['Compliant', 'Gap', 'Compliant', 'Compliant', 'Compliant'],
#  '19.3': ['Clarification', 'Compliant', 'Compliant', 'Clarification', 'Gap'],
#  '19.4': ['Gap', 'Compliant', 'Gap', 'Compliant', 'Compliant'],
#  '19.5': ['Compliant', 'Compliant', 'Compliant', 'Gap', 'Compliant'],
#  '19.6': ['Compliant', 'Gap', 'Compliant', 'Compliant', 'Compliant'],
#  '19.7': [nan, 'Compliant', 'Gap', nan, 'Gap'],
#  '19.8': ['Compliant', 'Compliant', 'Compliant', 'Compliant', 'Compliant'],
#  '19.9': [nan, 'Compliant', 'Compliant', 'Compliant', 'Compliant'],
#  '20': ['Compliant', 'Gap', 'Clarification', 'Compliant', 'Compliant'],
#  '20.1': ['Clarification',
#   'Compliant',
#   'Clarification',
#   'Clarification',
#   'Clarification'],
#  '20.2': ['Clarification', 'Gap', 'Compliant', 'Gap', 'Clarification'],
#  '20.3': ['Compliant', 'Compliant', 'Compliant', 'Compliant', 'Compliant'],
# ...
